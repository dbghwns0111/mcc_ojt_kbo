# %%
import pandas as pd

path = '../data/player_info/player_attributes.csv'
df = pd.read_csv(path, encoding='utf-8-sig')

name_counts = df['선수명'].value_counts()
print(name_counts[name_counts >= 2])
# Out:
# 선수명
# 김민수     4
# 김태훈     4
# 박건우     4
# 이선우     3
# 이승현     3
# 박세웅     2
# 스미스     2
# 김현수     2
# 산체스     2
# 김민혁     2
# 김성진     2
# 김현준     2
# 수아레즈    2
# 박성빈     2
# 박시원     2
# 데이비슨    2
# 김태현     2
# 김태형     2
# 김동혁     2
# 김상수     2
# 김서준     2
# 박준영     2
# 김민석     2
# 김재현     2
# 김대우     2
# 김민규     2
# 앤더슨     2
# 양현종     2
# 이명기     2
# 이병규     2
# 이병헌     2
# 박진우     2
# 이승민     2
# 이승헌     2
# 김성민     2
# 이원석     2
# 이원재     2
# 이재원     2
# 이주형     2
# 최원준     2
# 한승혁     2
# Name: count, dtype: int64
