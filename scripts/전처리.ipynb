# %%
import pandas as pd

df_games = pd.read_csv('../data_etl/all_years_Games_all.csv')
df_hitters = pd.read_csv('../data_etl/all_years_hitter_daily.csv')

# hitter 데이터의 game_id 중에서 df_games의 game_id에 없는 것 찾기
missing_game_ids = set(df_hitters['GAME_ID']) - set(df_games['GAME_ID'])
missing_game_ids
# Out:
# set()
